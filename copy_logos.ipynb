# %%
import shutil
shutil.copy('/workspaces/zef-/NEWS ASSETS/mlbb news.png', '/workspaces/zef-/public/games/mlbb-msc-2026.png')
print("Done")
# Out:
# OK: BGMI.jpeg -> bgmi.jpeg
# OK: valorant.png -> valorant.png
# OK: clash of clans.png -> clash-of-clans.png
# OK: clash royale.png -> clash-royale.png
# OK: free fire max.png -> free-fire-max.png
# OK: league of legends.png -> league-of-legends.png
# OK: pokemon unite.png -> pokemon-unite.png
#
# Files in destination:
#   .gitkeep (0 bytes)
#   bgmi.jpeg (22892 bytes)
#   clash-of-clans.png (660271 bytes)
#   clash-royale.png (164379 bytes)
#   free-fire-max.png (4117 bytes)
#   league-of-legends.png (150611 bytes)
#   pokemon-unite.png (406528 bytes)
#   valorant.png (20661 bytes)

# %%
import shutil
shutil.copy('/workspaces/zef-/NEWS ASSETS/mlbb news.png', '/workspaces/zef-/public/games/mlbb-msc-2026.png')
print("Copied mlbb news.png to public/games/mlbb-msc-2026.png")
