# %%
import shutil, os
shutil.copy2("/workspaces/zef-/game logos/pubg mobile.png", "/workspaces/zef-/public/games/pubg-mobile.png")
print("Copied pubg mobile.png -> pubg-mobile.png")
for f in sorted(os.listdir("/workspaces/zef-/public/games")):
    print(f"  {f}")
